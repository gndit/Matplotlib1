# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,10]
y = [1,3,4,5,7,6,8,9]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("our first plot")
plt.show()

# %%
import matplotlib.pyplot as plt
a = [2,17,8,14,15,4,13,46]
b = [9,1,3,4,5,2,22,100]
plt.plot(a,b)
plt.xlabel("a-axis")
plt.ylabel("b-axis")
plt.title("second plot")
plt.show()
